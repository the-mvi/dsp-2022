# %% [markdown]
# # Лабораторная работа №2: Моделирование и анализ линейных комбинаций дискретных сигналов
#
# Выполнили студенты гр. 9381 Шахин Никита и Аухадиев Александр. Вариант №7

# %% [markdown]
# ## Цель работы
#
# Изучить математическое описание линейных комбинаций дискретных гармонических сигналов и овладеть программными средствами их моделирования.

# %% [markdown]
# ## Основные теоретические положения
#
# Дискретный прямоугольный импульс:
# $$
# s(k) = \begin{equation*}
# \begin{cases}
#    U, n_0 \leq k \leq n_0 + n_{imp} - 1\\
#    0, иначе
#  \end{cases}
# \end{equation*}
# $$
#
# Линейная комбинация дискретных гармонических сигналов: $s(k) = a_1x_1(k) + a_2 x_2 (k) + a_3 x_3 (k)$, где $x_i(k) = B_i\sin(\hat\omega_i k)$, $i = 1,2,3$
#
# Дискретный гармонический сигнал $s(k)$: $s(k) = C\cos(\hat\omega_0 k)$

# %% [markdown]
# ## Постановка задачи
#
# С помощью программных средств провести моделирование и анализ линейных комбинаций дискретных гармонических последовательностей. Результаты подкрепить соответствующими графиками и выводами.
#
# 1. Смоделировать дискретный прямоугольный импульс:
#
# $$
# s_1(k) = \begin{equation*}
# \begin{cases}
#    U, n_0 \leq k \leq n_0 + n_{imp} - 1\\
#    0, иначе
#  \end{cases}
# \end{equation*}
# $$
#
# на основе дискретного единичного скачка $\sigma_d(k)$ из л/р №1 с выводом графика на интервале времени $n \in [0,N-1]$. Пояснить как выполняется моделирование импульса.
#
# 2. Смоделировать линейную комбинацию дискретных гармонических сигналов $s_2(k)$:
#
# $s_2(k) = a_1x_1(k) + a_2 x_2 (k) + a_3 x_3 (k)$, где $x_i(k) = B_i\sin(\hat\omega_i k)$, $i = 1,2,3$
#
# с выводом графиков последовательностей $x_i(k)$ и $s_2(k)$ на интервале времени $n \in [0, 5N - 1]$. Вычислить среднее значение (идентификатор `mean_s2`), энергию (идентификатор `Е`) и среднюю мощность последовательности $s_2(k)$ (идентификатор `Р`). Пояснить:
#
#   * операции при моделировании линейной комбинации сигналов $s_2(k)$
#   * как определяют указанные характеристики.
#
# 3. Вывести график дискретного сигнала $s_3(k)$, представляющего собой дискретный гармонический сигнал $s(k)$: $s(k) = C\cos(\hat\omega_0 k)$ с экспоненциальной огибающей $|a|^k$, на интервале времени $n \in [0, N-1]$. Привести  аналитическую формулу дискретного сигнала $s_3(k)$ и пояснить операции при его моделировании.
#
# 4. Вывести график пяти периодов периодической последовательности $s_4(k)$ дискретных прямоугольных импульсов амплитуды $U$ и длительности $n_{imp}$ с периодом, вдвое большим длительности импульса. Пояснить операции при моделировании периодической последовательности.
#
# 5. Сделать выводы.

# %% [markdown]
# ## Выполнение работы
#
# Начальные условия:
#
# |Переменная||Назначение              ||Значение                                  ||Идентификатор|
# |----------||------------------------||------------------------------------------||-------------|
# |$N_{бр}$  ||Номер бригады           ||$N_{бр}$                                  ||Nb = 7     |
# |$N$       ||Длина последовательности||$N$ = 30 + $N_{бр}$ mod 5                 ||N = 32     |
# |$a$       ||Основание экспоненты    ||$a$ = $(-1)^{N_{бр}}$(0.8 + 0.005$N_{бр}$)||a = -0.835 |
# |$C$       ||Амплитуда гармонического сигнала||$C$ = 1 + $N_{бр}$ mod 5         ||C = 3      |
# |$\hat\omega_0$(рад)||Частота гармонического сигнала||$\hat\omega_0$ = $\pi$/(6 + $N_{бр}$ mod 5)||w0=0.392699|
# |$U$||Амплитуда импульса||$U = N_{бр}$||U = 7|
# |$n_0$||Начальный момент импульса||$n_0$ = 3 + $N_{бр}$ mod 5||n0 = 5|
# |$n_{imp}$||Длина импульса||$n_{imp}$ = 5 + $N_{бр}$ mod 5|| n_imp = 7|
# |$B_1$||Амплитуды гармонических сигналов||$B_1$ = 1.5 + $N_{бр}$ mod 5||B1 = 3.5|
# |$B_2$|| ||$B_2$ = 5.7 - $N_{бр}$ mod 5|| B2 = 3.7|
# |$B_3$|| ||$B_3$ = 2.2 + $N_{бр}$ mod 5|| B3 = 4.2|
# |$\hat\omega_1$||Частоты гармонических сигналов||$\hat\omega_1$ = $\pi$/(4 + $N_{бр}$ mod 5)||w1 = 0.523599|
# |$\hat\omega_2$|| ||$\hat\omega_1$ = $\pi$/(8 + $N_{бр}$ mod 5)|| w2 = 0.314159|
# |$\hat\omega_3$|| ||$\hat\omega_1$ = $\pi$/(16 + $N_{бр}$ mod 5)|| w3 = 0.174533|
# |$a_1$||Коэффициенты линейной комбинации гармонических сигналов||$a_1$ = 1.5 - $N_{бр}$ mod 5||a1 = -0.5|
# |$a_2$|| ||$a_2$ = 0.7 + $N_{бр}$ mod 5|| a2 = 2.7|
# |$a_3$|| ||$a_3$ = 1.4 + $N_{бр}$ mod 5||a3 = 3.4|
#
# Импорт необходимых библиотек, определение переменных и используемых функций:

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

#Исходные данные:
def get_var():
    variables = {'Nb': 7}
    variables['N'] = 30 + variables['Nb'] % 5
    variables['T'] = 0.0005 * (1 + variables['Nb'] % 3)
    variables['a'] = (-1) ** variables['Nb'] * (0.8 + 0.005 * variables['Nb'])
    variables['C'] = 1 + variables['Nb'] % 5
    variables['w0'] = math.pi / (6 + variables['Nb'] % 5)
    variables['U'] = variables['Nb']
    variables['n0'] = variables['Nb'] % 5 + 3
    variables['n_imp'] = variables['Nb'] % 5 + 5
    variables['B1'] = 1.5 + variables['Nb'] % 5
    variables['B2'] = 5.7 - variables['Nb'] % 5
    variables['B3'] = 2.2 + variables['Nb'] % 5
    variables['w1'] = math.pi / (4 + variables['Nb'] % 5)
    variables['w2'] = math.pi / (8 + variables['Nb'] % 5)
    variables['w3'] = math.pi / (16 + variables['Nb'] % 5)
    variables['a1'] = 1.5 - variables['Nb'] % 5
    variables['a2'] = 0.7 + variables['Nb'] % 5
    variables['a3'] = 1.4 + variables['Nb'] % 5
    variables['x1'] = lambda k: variables['B1'] * np.sin(variables['w1'] * k)
    variables['x2'] = lambda k: variables['B2'] * np.sin(variables['w2'] * k)
    variables['x3'] = lambda k: variables['B3'] * np.sin(variables['w3'] * k)
    return variables

vv = get_var()
x = np.linspace(0, (vv['N'] - 1) * vv['T'])
x_norm = np.linspace(0, vv['N'] - 1, 33)

def rect(_x, m=vv['n0']):
    y = np.zeros(_x.shape)
    y[(m <= _x) & (_x <= m + vv['n_imp'] - 1)] = vv['U']
    return y

# %% [markdown]
# 1. Смоделируем дискретный прямоугольный импульс:
#
# $s_1(k) = \begin{equation*}
# \begin{cases}
#    U, n_0 \leq k \leq n_0 + n_{imp} - 1\\
#    0, иначе
#  \end{cases}
# \end{equation*}$
#
# на основе дискретного единичного скачка $\sigma_d(k)$ из л/р №1 с выводом графика на интервале времени $n \in [0,N-1]$.

# %%
plt.stem(x_norm, rect(x_norm))
plt.grid()
plt.show()

# %% [markdown]
# Моделирование прямоугольного импульса происходит следующим образом:
# 1. Генерируется массив из нулей с количеством элементов, соответствующим интервалу времени.
# 2. Каждому элементу, удовлетворяющему условию, присваивается U.

# %% [markdown]
# 2. Смоделируем линейную комбинацию дискретных гармонических сигналов $s_2(k)$:
#
# $s_2(k) = a_1x_1(k) + a_2 x_2 (k) + a_3 x_3 (k)$, где $x_i(k) = B_i\sin(\hat\omega_i k)$, $i = 1,2,3$
#
# с выводом графиков последовательностей $x_i(k)$ и $s_2(k)$ на интервале времени $n \in [0, 5N - 1]$ и вычислим среднее значение (идентификатор `mean_s2`), энергию (идентификатор `Е`) и среднюю мощность последовательности $s_2(k)$ (идентификатор `Р`)

# %%
def s4(_x):
    return vv['a1'] * vv['x1'](_x) + vv['a2'] * vv['x2'](_x) + vv['a3'] * vv['x3'](_x)

x_7 = np.linspace(0, 5 * vv['N'] - 1, 5 * vv['N'])

ans = s4(x_7)
plt.stem(x_7, ans)
plt.title("График последовательности s4(k)")
plt.grid()
plt.show()

# %%
plt.stem(x_7, vv['x1'](x_7))
plt.title("График последовательности x1(k)")
plt.grid()
plt.show()

# %%
plt.stem(x_7, vv['x2'](x_7))
plt.title("График последовательности x2(k)")
plt.grid()
plt.show()

# %%
plt.stem(x_7, vv['x3'](x_7))
plt.title("График последовательности x3(k)")
plt.grid()
plt.show()
print('Среднее - {}, Энергия - {}, Мощность - {}'.format(ans.mean(), np.power(ans, 2).sum(), np.power(ans, 2).mean()))
# Out:
# Среднее - 0.9482303675189678, Энергия - 24233.794012941784, Мощность - 151.46121258088615

# %% [markdown]
# Операции при моделировании линейной комбинации сигналов:
#
# 1. Вычисление дискретного нормированного времени
# 2. Вычисление матрицы дискретных гармоник
# 3. Линейная комбинация дискретных гармоник
#
# Определение характеристик:
#
# 1. Среднее значение: $M = {1 \over N} \sum\limits_{i=0}^{N-1} x_i$
#
# 2. Энергия: $E = \sum x^2$
#
# 3. Мощность: $P = {{\sum x^2} \over N}$

# %% [markdown]
# 3. Выведем график дискретного сигнала $s_3(k)$, представляющего собой дискретный гармонический сигнал $s(k)$: $s(k) = C\cos(\hat\omega_0 k)$ с экспоненциальной огибающей $|a|^k$, на интервале времени $n \in [0, N-1]$.

# %%
def s5(_x):
    return (np.abs(vv['a']) ** _x) * np.cos(vv['w0'] * _x) * vv['C']

plt.stem(x_norm, s5(x_norm))
plt.title("График дискретной затухающей синусоиды s3(k)")
plt.grid()
plt.show()

# %% [markdown]
# Операции при моделировании данного сигнала:
#
# 1. Расчёт времени на интервале $n \in [0, N-1]$.
# 2. Расчёт дискретной затухающей синусоиды.
#
# Формула дискретного сигнала $s_3$: $s_3(k) = |a|^k C \cos(\hat\omega_0 k)$

# %% [markdown]
# 4. Выведем график пяти периодов периодической последовательности $s_4(k)$ дискретных прямоугольных импульсов амплитуды $U$ и длительности $n_{imp}$ с периодом, вдвое большим длительности импульса.

# %%
x_9 = np.linspace(0, 3 * vv['N'] - 1, 3 * vv['N'])
y = np.zeros(shape=x_9.shape)

for i in range(5):
    y += rect(x_9, 2 * vv['n_imp'] * i)

plt.stem(x_9, y)
plt.title("График пяти периодов периодической последовательности s4(k)")
plt.grid()
plt.show()

# %% [markdown]
# Операции при моделировании периодической последовательности:
#
# 1. Генерируем 5 прямоугольных импульсов с соответствующим смещением.
# 2. Складываем их.

# %% [markdown]
# ## Выводы
#
# Было изучено математическое описание линейных комбинаций дискретных гармонических сигналов и получены навыки их моделирования программными средствами. Был исследован дискретный прямоугольный импульс $s_1$ на интервале времени $k$ на основе цифрового единичного скачка. Была исследована линейная комбинация дискретных гармонических сигналов $s_2$ на интервале времени $n \in [0; (5N − 1)]$; были вычислены её среднее значение, энергия и средняя мощность. Была исследована дискретная затухающая синусоида $s_3$ на интервале времени $n \in [0; N − 1]$; приведена аналитическая формула дискретного сигнала $s_3(k)$. Была исследована периодическая последовательность дискретных прямоугольных импульсов $s_4$ на интервале времени $k$.
